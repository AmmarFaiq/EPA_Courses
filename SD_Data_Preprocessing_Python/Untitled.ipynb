# %%
import matplotlib as plt
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import pysd
simple_model_path = 'D:/OneDrive/EPA 2017/Q3/Advanced System Dynamics/3.1 Assignments/PopulationWorldV03_forcalibration_urban_district.mdl'

# %%
model = pysd.read_vensim(simple_model_path)
values = model.run()
values.head(5)
# Out:
# ---------------------------------------------------------------------------
# IncompleteParseError                      Traceback (most recent call last)
# <ipython-input-16-297afbb92ee4> in <module>()
# ----> 1 model = pysd.read_vensim(simple_model_path)
#       2 values = model.run()
#       3 values.head(5)
#
# D:\Anaconda\lib\site-packages\pysd\pysd.py in read_vensim(mdl_file)
#      44     from .py_backend.vensim.vensim2py import translate_vensim
#      45     from .py_backend import functions
# ---> 46     py_model_file = translate_vensim(mdl_file)
#      47     model = functions.Model(py_model_file)
#      48     model.mdl_file = mdl_file
#
# D:\Anaconda\lib\site-packages\pysd\py_backend\vensim\vensim2py.py in translate_vensim(mdl_file)
#     850
#     851     for section in file_sections:
# --> 852         translate_section(section, macro_list)
#     853
#     854     return outfile_name
#
# ...

# %%
values.plot()
plt.show()
# plt.ylabel('Degrees F')
# plt.xlabel('Minutes')
# plt.legend(loc='center left', bbox_to_anchor=(1,.5));
