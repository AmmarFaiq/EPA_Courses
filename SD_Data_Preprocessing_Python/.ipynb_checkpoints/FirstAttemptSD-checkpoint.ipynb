# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

from math import sin, cos, atan2, sqrt, pi, radians
#!conda install -c conda-forge geopandas

# %%
#path ='D:\Jupyter_File\Python_Challenge_SD\country-capitals.csv'

df = pd.read_csv("country-capitals.csv",index_col="CountryName", error_bad_lines=False)
df.head(10)
# Out:
# b'Skipping line 229: expected 6 fields, saw 7\nSkipping line 240: expected 6 fields, saw 7\n'
#                                                 CapitalName  CapitalLatitude  \
# CountryName
# Somaliland                                         Hargeisa         9.550000
# South Georgia and South Sandwich Islands  King Edward Point       -54.283333
# French Southern and Antarctic Lands       Port-aux-Français       -49.350000
# Palestine                                         Jerusalem        31.766667
# Aland Islands                                     Mariehamn        60.116667
# Nauru                                                 Yaren        -0.547700
# Saint Martin                                        Marigot        18.073100
# Tokelau                                               Atafu        -9.166667
# Western Sahara                                     El-Aaiún        27.153611
# Afghanistan                                           Kabul        34.516667
#
#                                           CapitalLongitude CountryCode  \
# CountryName
# Somaliland                                       44.050000         NaN
# South Georgia and South Sandwich Islands        -36.500000          GS
# French Southern and Antarctic Lands              70.216667          TF
# Palestine                                        35.233333          PS
# Aland Islands                                    19.900000          AX
# Nauru                                           166.920867          NR
# Saint Martin                                    -63.082200          MF
# Tokelau                                        -171.833333          TK
# Western Sahara                                  -13.203333          EH
# Afghanistan                                      69.183333          AF
#
#                                           ContinentName
# CountryName
# Somaliland                                       Africa
# South Georgia and South Sandwich Islands     Antarctica
# French Southern and Antarctic Lands          Antarctica
# Palestine                                          Asia
# Aland Islands                                    Europe
# Nauru                                         Australia
# Saint Martin                              North America
# Tokelau                                       Australia
# Western Sahara                                   Africa
# Afghanistan                                        Asia

# %%
# Drop the data that have NaN values
df = df.dropna()

# %%
# Function for calculating the distance between two coordinates
# Haversine formula
def distance(loc1, loc2, R = 6371):
    
    # Change the value into radians
    lat1 = radians(float(loc1[0]))
    lat2 = radians(float(loc2[0]))
    
    #Calulate the difference between the coordinates between two points (Latitude and Longitude)
    deltalat = radians(float(loc2[0])-float(loc1[0])) 
    deltalon = radians(float(loc2[1])-float(loc1[1]))
    
    # Haversine formula
    a = sin(deltalat/2) * sin(deltalat/2) + cos(lat1) * cos(lat2) * sin(deltalon/2) * sin(deltalon/2);
    c = 2 * atan2(sqrt(a),sqrt(1-a));

    d = R * c;
    
    return d

# %%
# Create new blank data frame to input the distance
new_df = pd.DataFrame()

# Loop from to calculate distance 
for i in range(len(df)):
    
    #empty list in order to store distance between two countries 
    d = []
    for j in range(len(df)):
        
        #add each value into the list one by one
        d.append(distance(df.iloc[i][['CapitalLatitude', 'CapitalLongitude']], df.iloc[j][['CapitalLatitude', 'CapitalLongitude']]))
    
    # Change new dataframe column name with the first index name (country)
    new_df[df.index[i]] = d

# %%
# Change the name of the index from number to countries' name

new_df.index = df.index
new_df.tail()
# Out:
#                                     Somaliland  \
# CountryName
# Northern Cyprus                    3049.573971
# Hong Kong                          4988.745576
# Heard Island and McDonald Islands  4988.745576
# British Indian Ocean Territory     3656.773937
# Macau                              4988.745576
#
#                                    South Georgia and South Sandwich Islands  \
# CountryName
# Northern Cyprus                                                11972.729407
# Hong Kong                                                       6895.514642
# Heard Island and McDonald Islands                               6895.514642
# British Indian Ocean Territory                                 10545.879908
# Macau                                                           6895.514642
#
#                                    French Southern and Antarctic Lands  \
# CountryName
# Northern Cyprus                                           10078.313254
# Hong Kong                                                  8591.176356
# Heard Island and McDonald Islands                          8591.176356
# British Indian Ocean Territory                             4680.206897
# Macau                                                      8591.176356
#
#                                      Palestine  Aland Islands         Nauru  \
# CountryName
# Northern Cyprus                     417.480943    2937.107142  13861.080197
# Hong Kong                          5116.806181    6901.202231  18559.501176
# Heard Island and McDonald Islands  5116.806181    6901.202231  18559.501176
# British Indian Ocean Territory     5866.910463    8785.250711  10498.373337
# Macau                              5116.806181    6901.202231  18559.501176
#
#                                    Saint Martin       Tokelau  Western Sahara  \
# CountryName
# Northern Cyprus                     9423.880017  16153.600070     4478.755569
# Hong Kong                           7173.029033  18652.545309     3332.790802
# Heard Island and McDonald Islands   7173.029033  18652.545309     3332.790802
# British Indian Ocean Territory     15053.539100  12667.145818     9945.937567
# Macau                               7173.029033  18652.545309     3332.790802
#
#                                    Afghanistan     ...       \
# CountryName                                        ...
# Northern Cyprus                    3251.334689     ...
# Hong Kong                          8114.252976     ...
# Heard Island and McDonald Islands  8114.252976     ...
# British Indian Ocean Territory     4662.091766     ...
# Macau                              8114.252976     ...
#
#                                    Wallis and Futuna        Yemen  \
# CountryName
# Northern Cyprus                         16554.012012  2455.570820
# Hong Kong                               18227.713406  5144.325892
# Heard Island and McDonald Islands       18227.713406  5144.325892
# British Indian Ocean Territory          12534.532503  3999.514703
# Macau                                   18227.713406  5144.325892
#
#                                         Zambia     Zimbabwe   Antarctica  \
# CountryName
# Northern Cyprus                    5651.971223  5898.476118  5220.977240
# Hong Kong                          3547.632406  3929.204055     0.000000
# Heard Island and McDonald Islands  3547.632406  3929.204055     0.000000
# British Indian Ocean Territory     4884.129531  4627.714724  8066.887365
# Macau                              3547.632406  3929.204055     0.000000
#
#                                    Northern Cyprus    Hong Kong  \
# CountryName
# Northern Cyprus                            0.00000  5220.977240
# Hong Kong                               5220.97724     0.000000
# Heard Island and McDonald Islands       5220.97724     0.000000
# British Indian Ocean Territory          6247.49674  8066.887365
# Macau                                   5220.97724     0.000000
#
#                                    Heard Island and McDonald Islands  \
# CountryName
# Northern Cyprus                                          5220.977240
# Hong Kong                                                   0.000000
# Heard Island and McDonald Islands                           0.000000
# British Indian Ocean Territory                           8066.887365
# Macau                                                       0.000000
#
#                                    British Indian Ocean Territory        Macau
# CountryName
# Northern Cyprus                                       6247.496740  5220.977240
# Hong Kong                                             8066.887365     0.000000
# Heard Island and McDonald Islands                     8066.887365     0.000000
# British Indian Ocean Territory                           0.000000  8066.887365
# Macau                                                 8066.887365     0.000000
#
# [5 rows x 243 columns]

# %%
# Convert dataframe into CSV files
new_df.to_csv("World Capital Distance.csv")
